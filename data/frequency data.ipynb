# %%
import pandas as pd
import io
from google.colab import files

# %%
uploaded = files.upload()

data = pd.read_csv(io.BytesIO(uploaded['tweets.csv']))
data_original = data
data
# Out:
#      <input type="file" id="files-90e852fb-3bbe-46b4-af2c-3b566eb60d33" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90e852fb-3bbe-46b4-af2c-3b566eb60d33">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data['Date'].astype('str')
# Out:
# 0        2023-02-16 23:48:21+00:00
# 1        2023-02-16 23:45:56+00:00
# 2        2023-02-16 23:44:19+00:00
# 3        2023-02-16 23:35:00+00:00
# 4        2023-02-16 23:30:16+00:00
#                    ...
# 11206    2023-02-06 12:31:17+00:00
# 11207    2023-02-06 10:12:20+00:00
# 11208    2023-02-06 08:11:06+00:00
# 11209    2023-02-06 05:02:06+00:00
# 11210    2023-02-06 04:49:47+00:00
# Name: Date, Length: 11211, dtype: object

# %%
data['Date_new'] = [x[0:10] for x in data['Date']]
data
# Out:
#        Unnamed: 0                       Date  \
# 0               0  2023-02-16 23:48:21+00:00
# 1               1  2023-02-16 23:45:56+00:00
# 2               2  2023-02-16 23:44:19+00:00
# 3               3  2023-02-16 23:35:00+00:00
# 4               4  2023-02-16 23:30:16+00:00
# ...           ...                        ...
# 11206       11206  2023-02-06 12:31:17+00:00
# 11207       11207  2023-02-06 10:12:20+00:00
# 11208       11208  2023-02-06 08:11:06+00:00
# 11209       11209  2023-02-06 05:02:06+00:00
# 11210       11210  2023-02-06 04:49:47+00:00
#
#                                                  Content  \
# 0      #Turkey's #Erdogan will be digging his grave i...
# 1      #Turkey's #Erdogan will be digging his grave i...
# 2      Mustafa, who was rescued tonight at the 261st ...
# 3      #ICYMI: Dartmouth-based @ninelocksbrew is aimi...
# 4      ‘What we need to ask ourselves is how Muslims ...
# ...                                                  ...
# ...

# %%
res = data['Date_new'].value_counts()
res
# Out:
# 2023-02-09    2846
# 2023-02-08    2268
# 2023-02-10    2015
# 2023-02-11    1096
# 2023-02-12    1061
# 2023-02-13     528
# 2023-02-14     475
# 2023-02-15     339
# 2023-02-16     285
# 2023-02-07     257
# 2023-02-06      41
# Name: Date_new, dtype: int64

# %%
res.to_csv('frequency.csv')

# %%
# count number of likes


data = data_original

data.head()

from google.colab import files
data.to_csv('dweeds.csv', encoding = 'utf-8-sig') 
files.download('dweeds.csv')

# %%
days_and_likes = {}
row_num = 0
for day in set(data['Date_new']):
  tweets_on_day = data.loc[data['Date_new'] == day]
  print(day)
  for idx, tweet in tweets_on_day.iterrows():
    if day not in days_and_likes.keys():
      days_and_likes[day] = 0
    likes_on_tweet = tweet['# of likes']
    days_and_likes[day] += int(likes_on_tweet)
    row_num += 1
    # print("row num = " + str(row_num))

print(days_and_likes)
# Out:
# 2023-02-06
# 2023-02-14
# 2023-02-15
# 2023-02-07
# 2023-02-10
# 2023-02-09
# 2023-02-12
# 2023-02-16
# 2023-02-13
# 2023-02-08
# 2023-02-11
# {'2023-02-06': 2313, '2023-02-14': 14127, '2023-02-15': 12233, '2023-02-07': 71103, '2023-02-10': 95064, '2023-02-09': 234141, '2023-02-12': 332731, '2023-02-16': 8654, '2023-02-13': 19656, '2023-02-08': 212916, '2023-02-11': 44849}

# %%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
