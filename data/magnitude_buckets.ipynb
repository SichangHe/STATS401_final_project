# %%
import pandas as pd
import io
from google.colab import files

# %%
uploaded = files.upload()
#upload earthquake.csv

mags = pd.read_csv(io.BytesIO(uploaded['earthquake_mags.csv']))

mags_original = mags
# Out:
#      <input type="file" id="files-e4eb1cc6-288f-4c97-b506-839fe5a37b19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4eb1cc6-288f-4c97-b506-839fe5a37b19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
mags.head()
# Out:
#    mag
# 0  5.2
# 1  5.2
# 2  5.0
# 3  6.1
# 4  5.2

# %%
mag_counts = mags.value_counts()
counts_list = mag_counts.tolist()
# mags_list = mag_counts['mag'].tolist()

# %%
print(counts_list)
# Out:
# [2529, 1794, 1392, 1042, 776, 605, 438, 374, 273, 222, 189, 144, 105, 102, 70, 51, 47, 33, 26, 24, 15, 12, 10, 9, 8, 6, 5, 5, 4, 3, 2, 1, 1, 1, 1, 1, 1]

# %%
print(mag_counts)
# Out:
# mag
# 5.00    2529
# 5.10    1794
# 5.20    1392
# 5.30    1042
# 5.40     776
# 5.50     605
# 5.60     438
# 5.70     374
# 5.80     273
# 5.90     222
# 6.00     189
# 6.10     144
# 6.20     105
# 6.30     102
# 6.40      70
# 6.50      51
# 6.60      47
# 6.70      33
# 6.90      26
# 6.80      24
# 7.00      15
# 7.30      12
# 7.10      10
# 7.20       9
# 7.70       8
# 7.40       6
# 7.80       5
# 7.50       5
# 7.60       4
# 7.90       3
# 8.30       2
# 8.10       1
# 8.16       1
# 6.51       1
# 5.67       1
# 5.26       1
# 9.10       1
# dtype: int64

# %%
mags_list = [5.00,
5.10,
5.20,
5.30,
5.40,
5.50,
5.60,
5.70,
5.80,
5.90,
6.00,
6.10,
6.20,
6.30,
6.40,
6.50,
6.60,
6.70,
6.90,
6.80,
7.00,
7.30,
7.10,
7.20,
7.70,
7.40,
7.80,
7.50,
7.60,
7.90,
8.30,
8.10,
8.16,
6.51,
5.67,
5.26,
9.10]

# %%
import numpy as np
import matplotlib.pyplot as plt

print(len(mags_list))
print(len(counts_list))
print(len(list(np.log(counts_list))))
# Out:
# 37
# 37
# 37

# %%
model = np.poly1d(np.polyfit(mags_list, list(np.log(counts_list)), 1))
line = np.linspace(5.0, 9.1, 3)
plt.scatter(mags_list, list(np.log(counts_list)))
plt.plot(line, model(line))
plt.show()

# %%
from google.colab import files

mags_counts_df = pd.DataFrame([mags_list, counts_list]).transpose()
mags_counts_df.to_csv('mags_counts.csv', encoding = 'utf-8-sig') 
files.download('mags_counts.csv')
